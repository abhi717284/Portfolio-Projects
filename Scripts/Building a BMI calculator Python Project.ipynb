# %% [markdown]
# # BMI Calculator

# %%
# BMI = (weight in pounds / (height in inches * height in inches)) * 703

# %%
name = input("Enter your name: ")

weight = int(input("Enter your weight in pounds: "))

height = int(input("Enter your height in inches: "))

BMI = (weight / (height * height)) * 703
# Out:
# Enter your name:  Abhi
# Enter your weight in pounds:  161
# Enter your height in inches:  67

# %%
print(BMI)
# Out:
# 25.213410559144574

# %%
# Underweight	< 18.5	Increased
Normal Weight	18.5 - 24.9	Least
Overweight	25.0 - 29.9	Increased
Obese class I	30.0 - 34.9	High
Obese class II	35.0 - 39.9	Very high
Obese class III	>= 40.0	Extremely high

# %%
if BMI>0:
    if(BMI<18.5):
        print(name + ", You are underweight.")
    elif(BMI<=24.9):
        print(name + ", You are normal weight.")
    elif(BMI<=29.9):
        print(f"{name}, You are overweight.") # we can use f-string also.
    elif(BMI<=34.9):
        print(name + ", You are obese class I.")
    elif(BMI<=39.9):
        print(name + ", You are obese class II.")
    else:
        print(name + ", You are obese class III")
else:
    print("Enter a valid input!")
# Out:
# Abhi, You are overweight.
